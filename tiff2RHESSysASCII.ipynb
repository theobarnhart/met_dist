# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gdal
from gdalconst import GDT_Float32
from gdalconst import GA_ReadOnly
from osgeo import osr
import glob
import string

# %%
PatchRast = '/RHESSys/Comocreek/GRASScomo/barnhatb/cell/como_30m_patch.tif'
tifpath = './test/'

# %%
patch = gdal.Open(PatchRast, GA_ReadOnly)
patch = np.array(patch.GetRasterBand(1).ReadAsArray(), dtype=np.float64) # load the patch map into memory

# %%
patch
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])

# %%
plt.imshow(patch)

# %%
tiffs = glob.glob(tifpath+'*.tif')

# %%
tiffs
# Out:
# ['./test/temperature_2005_10_1.tif',
#  './test/precipitation_2005_10_1.tif',
#  './test/temperature_2005_10_2.tif',
#  './test/precipitation_2005_10_2.tif',
#  './test/temperature_2005_10_3.tif',
#  './test/precipitation_2005_10_3.tif',
#  './test/temperature_2005_10_4.tif',
#  './test/precipitation_2005_10_4.tif',
#  './test/temperature_2005_10_5.tif',
#  './test/precipitation_2005_10_5.tif',
#  './test/temperature_2005_10_6.tif',
#  './test/precipitation_2005_10_6.tif',
#  './test/temperature_2005_10_7.tif',
#  './test/precipitation_2005_10_7.tif',
#  './test/temperature_2005_10_8.tif',
#  './test/precipitation_2005_10_8.tif',
#  './test/temperature_2005_10_9.tif',
#  './test/precipitation_2005_10_9.tif',
#  './test/temperature_2005_10_10.tif',
#  './test/precipitation_2005_10_10.tif',
#  './test/temperature_2005_10_11.tif',
#  './test/precipitation_2005_10_11.tif',
#  './test/temperature_2005_10_12.tif',
#  './test/precipitation_2005_10_12.tif',
# ...

# %%
tif = tiffs[1]

# %%
tif.split('_')
# Out:
# ['./test/precipitation', '2005', '10', '1.tif']
